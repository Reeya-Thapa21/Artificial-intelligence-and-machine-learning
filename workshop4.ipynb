# %% [markdown]
# **: Building a Fully Connected Network (FCN) for
# Devnagari Digit Classification.**
#
# **Workshop4**

# %% [markdown]
# **Task 1: Data Preparation**
#
# **Loading the Data**
#
# • Download the provided folder that contains the Devnagari digits dataset.
#
# • Use the Python Imaging Library (PIL) to load and read the image files from the dataset.
#
# • Convert the images into Numpy arrays and normalize them to a range of 0-1.
#
# • use train folder for training and test for testing.
#
# • Extract the corresponding labels for each image.

# %%
import os
import numpy as np
from PIL import Image
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# **Set Path**
#
# Ensure that the images are resized to a consistent shape (e.g., 28x28).

# %%
train_dir = "dataset/Train/"
test_dir = "dataset/Test/"
img_size = 28

# %% [markdown]
# **Load Images Function**

# %%
def load_images(folder):
    images = []
    labels = []

    class_names = sorted(os.listdir(folder))
    class_map = {name: i for i, name in enumerate(class_names)}

    for class_name in class_names:
        class_path = os.path.join(folder, class_name)
        label = class_map[class_name]

        for file in os.listdir(class_path):
            img_path = os.path.join(class_path, file)

            img = Image.open(img_path).convert("L")
            img = img.resize((img_size, img_size))
            img = np.array(img) / 255.0

            images.append(img)
            labels.append(label)

    return np.array(images), np.array(labels)

# %% [markdown]
# **Load Dataset**

# %%
train_dir = "DevanagariHandwrittenDigitDataset/Train/"
test_dir = "DevanagariHandwrittenDigitDataset/Test/"

# %%
x_train, y_train = load_images(train_dir)
x_test, y_test = load_images(test_dir)

# %% [markdown]
# **Reshape + Encode**

# %%
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print(x_train.shape, y_train.shape)
# Out:
# (5340, 28, 28, 1) (5340, 10)

# %% [markdown]
# **Task 2: Build the FCN Model**
#
# **Model Architecture**
#
#
# • Create a Sequential model using Keras.
#
# • Add 3 hidden layers with the following number of neurons:
#
# – 1st hidden layer: 64 neurons
# – 2nd hidden layer: 128 neurons
# – 3rd hidden layer: 256 neurons
#
# • Use sigmoid activation functions for all hidden layers.
#
# • Add an output layer with 10 units with softmax (since Devnagari digits have 10 classes) and a
# softmax activation function.

# %%
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28, 1)),
    keras.layers.Dense(64, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(256, activation='sigmoid'),
    keras.layers.Dense(10, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **TASK 3: Compile Model**

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# **TASK 4: Train Model**

# %%
print(y_train.shape)
# Out:
# (5340, 10)

# %%
history = model.fit(
    x_train,
    y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6681 - loss: 1.0484 - val_accuracy: 0.0000e+00 - val_loss: 2.9534
# Epoch 2/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9497 - loss: 0.3263 - val_accuracy: 0.6901 - val_loss: 2.1660
# Epoch 3/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9944 - loss: 0.0547 - val_accuracy: 0.7416 - val_loss: 2.1719
# Epoch 4/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9965 - loss: 0.0225 - val_accuracy: 0.7425 - val_loss: 2.2480
# Epoch 5/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9986 - loss: 0.0142 - val_accuracy: 0.7509 - val_loss: 2.3136
# Epoch 6/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9988 - loss: 0.0101 - val_accuracy: 0.7528 - val_loss: 2.3651
# Epoch 7/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9991 - loss: 0.0078 - val_accuracy: 0.7537 - val_loss: 2.4050
# Epoch 8/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9993 - loss: 0.0066 - val_accuracy: 0.7519 - val_loss: 2.4456
# Epoch 9/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9995 - loss: 0.0051 - val_accuracy: 0.7509 - val_loss: 2.4779
# Epoch 10/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9995 - loss: 0.0042 - val_accuracy: 0.7528 - val_loss: 2.5131
# Epoch 11/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9995 - loss: 0.0033 - val_accuracy: 0.7547 - val_loss: 2.5481
# Epoch 12/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9995 - loss: 0.0028 - val_accuracy: 0.7509 - val_loss: 2.5720
# Epoch 13/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9998 - loss: 0.0023 - val_accuracy: 0.7556 - val_loss: 2.6013
# Epoch 14/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9995 - loss: 0.0020 - val_accuracy: 0.7556 - val_loss: 2.6263
# Epoch 15/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9998 - loss: 0.0017 - val_accuracy: 0.7509 - val_loss: 2.6449
# Epoch 16/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9998 - loss: 0.0015 - val_accuracy: 0.7537 - val_loss: 2.6677
# Epoch 17/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.7556 - val_loss: 2.6873
# Epoch 18/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.7547 - val_loss: 2.7047
# Epoch 19/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.5845e-04 - val_accuracy: 0.7556 - val_loss: 2.7195
# Epoch 20/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.7423e-04 - val_accuracy: 0.7556 - val_loss: 2.7379

# %% [markdown]
# **Graphs**

# %%
import matplotlib.pyplot as plt

# Loss graph
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Loss")
plt.legend(["Train", "Validation"])
plt.show()

# Accuracy graph
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Accuracy")
plt.legend(["Train", "Validation"])
plt.show()

# %% [markdown]
# **TASK 5: Evaluate Model**

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test Accuracy:", test_acc)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2977 - loss: 7.6377
# Test Accuracy: 0.29766666889190674

# %% [markdown]
# **TASK 6: Save & Load Model**

# %%
# Save model
model.save("devnagari_model.h5")

# Load model
from tensorflow.keras.models import load_model
loaded_model = load_model("devnagari_model.h5")

# Evaluate again
loaded_model.evaluate(x_test, y_test)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2977 - loss: 7.6377
# [7.637679100036621, 0.29766666889190674]

# %% [markdown]
# **TASK 7: Prediction**

# %%
import numpy as np

predictions = model.predict(x_test)

predicted_labels = np.argmax(predictions, axis=1)

print("Predicted:", predicted_labels[0])
print("Actual:", np.argmax(y_test[0]))
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Predicted: 0
# Actual: 0
